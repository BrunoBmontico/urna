# %% [markdown]
# # Atividade Urna de Votação

# %%
from IPython.display import Image, display
display(Image(filename='urna.jpg', width=1000, height=500))  # Substitua 300 e 200 pelos valores desejados

# %% [markdown]
# ### Chegou o momento de concluirmos nosso ciclo de aprendizado em backend com Python! Desde as primeiras linhas de código até as estruturas condicionais e comparadores, exploramos um mundo de possibilidades. Agora, vamos aplicar nosso conhecimento em um projeto empolgante: a criação de uma "Urna Eletrônica" para as futuras votações na Escola SENAI Morvan Figueiredo.

# %% [markdown]
# ### Objetivo:
# ####   Criar uma urna eletrônica em Python para realizar uma simulação de votação entre candidatos fictícios na escola SENAI Morvan Figueiredo.

# %% [markdown]
# ### Descrição:
#
# #### Na "Urna Eletrônica" que vamos desenvolver, cada grupo de alunos será responsável por construir um sistema simulado de votação. Os candidatos imaginários, e todos terão a oportunidade de exercer seu direito de voto em um ambiente virtual.
#
# ### Passos da Atividade:
#
# #### Passo 1: Forme equipes no máximo 3 alunos.
#
#
#
# #### Passo 2: Criando os Candidatos e Partidos
#
# #### Criar uma lista de candidatos fictícios, atribuindo a cada um um nome, número e partido imaginário.
#
# #### Passo 3: Simulando a Votação
#
# #### Implemente um loop de votação que permita que os alunos escolham um candidato apenas pelo número.
# #### Use um dicionário para registrar a quantidade de votos que cada candidato recebeu.
#
# #### Passo 4: Contagem e Anúncio dos Resultados
#
# #### Ao encerrar a votação, exiba um relatório com os resultados da votação.
# #### Mostre os candidatos, seus números, partidos e a quantidade de votos recebidos por cada um.
# #### Anuncie o candidato vencedor, aquele que recebeu mais votos.

# %% [markdown]
# ### Lembrete:
# #### Esta atividade não é apenas sobre programar, mas também sobre compreender a importância das eleições, trabalhar em equipe e aplicar conceitos de programação em cenários do mundo real.

# %%
def opcoes():
        print('''
        1- Adicionar candidatos
        2- Remover candidatos
        3- ver candidatos
        4- iniciar votação
        ''')
def addCandidato():
    print('--REGISTRO DE CANDIDATOS--')
    nome = input('Nome: ')
    partido = input('Partido: ')
    numero = input('Numero: ')
    candidato = {'Candidato': nome, 'Partido': partido, 'Numero': numero}
    valor = numero
    if valor in numeros:
        print('--NUMERO DE CANDIDATO INVÁLIDO--')
    else:
        candidatos.append(candidato)
        print('--CANDIDATO CADASTRADO--')
        numeros.append(valor)
def rmvCandidato():
    c = 0
    if candidatos == []:
        print('--NENHUM CANDIDATO CADASTRADO--')
    elif candidatos != []:
        escolha = input('Numero do candidato que deseja remover.\n')
        for candidato in candidatos:
            for numero in candidato.values():
                if escolha == numero:
                    confirm = input('Confirma essa ação?(S ou N)\n').upper()
                    if confirm == 'S':
                        del candidatos[c], numeros[c]
                        c+=1
                        print('--CANDIDATO REMOVIDO--')
                    elif confirm == 'N':
                        print('--AÇÃO CANCELADA--')
            if escolha != numero:
                print('--CANDIDATO NÃO ENCONTRADO--') 
def verCandidatos():
    if candidatos == []:
        print('--NENHUM CANDIDATO CADASTRADO--')
    else:
        print('--LISTA DE CANDIDATOS--')
        for candidato in candidatos:
            print(candidato)
            
#---INICIAR VOTOS---
def opVotos():
    print('''
    1- votar em um candidato
    2- votar nulo
    3- votar branco''')

def votacao():
    print('--DIGITE O NUMERO DO CANDIDATO--')

# %%
candidatos = []
numeros = []

while True:
    opcoes()
    escolha = input()
    if escolha == '1': addCandidato()
    if escolha == '2': rmvCandidato()
    if escolha == '3': verCandidatos()
    if escolha == '4': opVotos()
# Out:
#         1- Adicionar candidatos
#         2- Remover candidatos
#         3- ver candidatos
#         4- iniciar votação
#
# 1
# --REGISTRO DE CANDIDATOS--
# Nome: asd
# Partido: asd
# Numero: 123
# --CANDIDATO CADASTRADO--
#
#         1- Adicionar candidatos
#         2- Remover candidatos
#         3- ver candidatos
#         4- iniciar votação
#
# 1
# --REGISTRO DE CANDIDATOS--
# Nome: asd
# Partido: asd
# Numero: 3456
# --CANDIDATO CADASTRADO--
#
#         1- Adicionar candidatos
#         2- Remover candidatos
#         3- ver candidatos
#         4- iniciar votação
#
# 2
# Numero do candidato que deseja remover.
# 123
# Confirma essa ação?(S ou N)
# s
# --CANDIDATO REMOVIDO--
#
#         1- Adicionar candidatos
#         2- Remover candidatos
#         3- ver candidatos
#         4- iniciar votação
#
# 2
# Numero do candidato que deseja remover.
# 3456
# Confirma essa ação?(S ou N)
# s
# --CANDIDATO REMOVIDO--
#
#         1- Adicionar candidatos
#         2- Remover candidatos
#         3- ver candidatos
#         4- iniciar votação

# %%
# if escolha == '4' and candidatos != []: 
#         while True:
#             print('--VOTAÇÃO--')
#             opVotos()
#             escolha = input()
#             if escolha == '1': 
#                 while escolha != '':
#                     votacao()
#     elif candidatos == []:
#         print('--CANDIDATOS INSUFICIENTES--')
